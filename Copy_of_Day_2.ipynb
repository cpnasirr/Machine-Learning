# %% [markdown]
# <a href="https://colab.research.google.com/github/cpnasirr/Machine-Learning/blob/Colab/Copy_of_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
myFile=files.upload()
# Out:
#      <input type="file" id="files-d0e6fc27-7bdb-4372-ae99-2a7d5c32a51a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0e6fc27-7bdb-4372-ae99-2a7d5c32a51a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv(next(iter(myFile)))
df
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 4       4  04/21/19     Sunday                  56                 35
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 11     11  04/28/19     Sunday                  85                 42
# ...

# %%
df.shape
# Out:
# (28, 12)

# %%
print(df.values)
# Out:
# [[0 '04/17/19' 'Wednesday' 187 89 17 41 22 0 0 0 0]
#  [1 '04/18/19' 'Thursday' 123 78 17 8 9 0 0 0 0]
#  [2 '04/19/19' 'Friday' 112 52 40 8 4 0 3 0 0]
#  [3 '04/20/19' 'Saturday' 101 69 9 38 2 0 3 0 0]
#  [4 '04/21/19' 'Sunday' 56 35 2 43 3 0 1 1 0]
#  [5 '04/22/19' 'Monday' 189 68 0 9 3 4 0 0 0]
#  [6 '04/23/19' 'Tuesday' 158 56 18 41 12 15 0 0 0]
#  [7 '04/24/19' 'Wednesday' 135 98 3 33 16 0 0 0 0]
#  [8 '04/25/19' 'Thursday' 52 25 7 3 16 0 0 0 0]
#  [9 '04/26/19' 'Friday' 198 76 8 29 15 0 32 0 0]
#  [10 '04/27/19' 'Saturday' 116 75 10 20 5 0 0 0 0]
#  [11 '04/28/19' 'Sunday' 85 42 22 4 2 0 0 0 0]
#  [12 '04/29/19' 'Monday' 109 46 8 13 9 15 1 0 1]
#  [13 '04/30/19' 'Tuesday' 79 40 2 9 12 0 0 0 1]
#  [14 '05/01/19' 'Wednesday' 127 90 0 10 7 0 0 0 1]
#  [15 '05/02/19' 'Thursday' 170 60 3 2 11 0 0 0 1]
#  [16 '05/03/19' 'Friday' 91 64 2 18 5 1 1 2 1]
#  [17 '05/04/19' 'Saturday' 58 34 4 5 3 0 1 0 1]
#  [18 '05/05/19' 'Sunday' 133 109 5 1 3 0 0 0 1]
# ...

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
df.Date
# Out:
# 0     04/17/19
# 1     04/18/19
# 2     04/19/19
# 3     04/20/19
# 4     04/21/19
# 5     04/22/19
# 6     04/23/19
# 7     04/24/19
# 8     04/25/19
# 9     04/26/19
# 10    04/27/19
# 11    04/28/19
# 12    04/29/19
# 13    04/30/19
# 14    05/01/19
# 15    05/02/19
# 16    05/03/19
# 17    05/04/19
# 18    05/05/19
# 19    05/06/19
# 20    05/07/19
# 21    05/08/19
# 22    05/09/19
# 23    05/10/19
# 24    05/11/19
# 25    05/12/19
# 26    05/13/19
# 27    05/14/19
# Name: Date, dtype: object

# %%
df[['Social Networking']].head(7)
# Out:
#    Social Networking
# 0                 89
# 1                 78
# 2                 52
# 3                 69
# 4                 35
# 5                 68
# 6                 56

# %%
df.Date
# Out:
# 0     04/17/19
# 1     04/18/19
# 2     04/19/19
# 3     04/20/19
# 4     04/21/19
# 5     04/22/19
# 6     04/23/19
# 7     04/24/19
# 8     04/25/19
# 9     04/26/19
# 10    04/27/19
# 11    04/28/19
# 12    04/29/19
# 13    04/30/19
# 14    05/01/19
# 15    05/02/19
# 16    05/03/19
# 17    05/04/19
# 18    05/05/19
# 19    05/06/19
# 20    05/07/19
# 21    05/08/19
# 22    05/09/19
# 23    05/10/19
# 24    05/11/19
# 25    05/12/19
# 26    05/13/19
# 27    05/14/19
# Name: Date, dtype: object

# %%
df['Date'].head()
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# Name: Date, dtype: object

# %%
df.Date.head()
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# Name: Date, dtype: object

# %%
df[['Date','Week Day']].head()
# Out:
#        Date   Week Day
# 0  04/17/19  Wednesday
# 1  04/18/19   Thursday
# 2  04/19/19     Friday
# 3  04/20/19   Saturday
# 4  04/21/19     Sunday

# %%
df.head(10)
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
# 5      5  04/22/19     Monday                 189                 68
# 6      6  04/23/19    Tuesday                 158                 56
# 7      7  04/24/19  Wednesday                 135                 98
# 8      8  04/25/19   Thursday                  52                 25
# 9      9  04/26/19     Friday                 198                 76
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# ...

# %%
df['Social Networking'].head(6)
# Out:
# 0    89
# 1    78
# 2    52
# 3    69
# 4    35
# 5    68
# Name: Social Networking, dtype: int64

# %%
df['Social Networking'].sort_values().head(10)
# Out:
# 8     25
# 25    28
# 17    34
# 4     35
# 26    37
# 13    40
# 27    41
# 11    42
# 22    42
# 12    46
# Name: Social Networking, dtype: int64

# %%
df['Social Networking'].sort_values(ascending=False).head(10)
# Out:
# 18    109
# 7      98
# 23     93
# 14     90
# 0      89
# 19     81
# 1      78
# 9      76
# 10     75
# 20     70
# Name: Social Networking, dtype: int64

# %%
df.sort_values('Social Networking').head(10)
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 8       8  04/25/19  Thursday                  52                 25
# 25     25  05/12/19    Sunday                  52                 28
# 17     17  05/04/19  Saturday                  58                 34
# 4       4  04/21/19    Sunday                  56                 35
# 26     26  05/13/19    Monday                  61                 37
# 13     13  04/30/19   Tuesday                  79                 40
# 27     27  05/14/19   Tuesday                  88                 41
# 11     11  04/28/19    Sunday                  85                 42
# 22     22  05/09/19  Thursday                  96                 42
# 12     12  04/29/19    Monday                 109                 46
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 8                       7      3            16                   0
# 25                      1      1             6                   0
# ...

# %%
df.sort_values('Social Networking',ascending=False).head(10)
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 18     18  05/05/19     Sunday                 133                109
# 7       7  04/24/19  Wednesday                 135                 98
# 23     23  05/10/19     Friday                 161                 93
# 14     14  05/01/19  Wednesday                 127                 90
# 0       0  04/17/19  Wednesday                 187                 89
# 19     19  05/06/19     Monday                 144                 81
# 1       1  04/18/19   Thursday                 123                 78
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 20     20  05/07/19    Tuesday                 110                 70
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 18                      5      1             3                   0
# ...

# %%
df.describe()
# Out:
#            index  Total Screen Time   Social Networking  \
# count  28.000000           28.000000          28.000000
# mean   13.500000          113.250000          60.714286
# std     8.225975           43.562322          22.853571
# min     0.000000           52.000000          25.000000
# 25%     6.750000           83.500000          41.750000
# 50%    13.500000          111.000000          58.000000
# 75%    20.250000          137.250000          76.500000
# max    27.000000          198.000000         109.000000
#
#        Reading and Reference      Other  Productivity  Health and Fitness  \
# count              28.000000  28.000000     28.000000           28.000000
# mean                8.714286  14.821429      9.071429            1.285714
# std                 9.340700  13.754605      6.097532            3.952094
# min                 0.000000   0.000000      2.000000            0.000000
# 25%                 2.000000   4.750000      3.000000            0.000000
# ...

# %%
#correlation
df['Week Day'].head(10)
# Out:
# 0    Wednesday
# 1     Thursday
# 2       Friday
# 3     Saturday
# 4       Sunday
# 5       Monday
# 6      Tuesday
# 7    Wednesday
# 8     Thursday
# 9       Friday
# Name: Week Day, dtype: object

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
df['Social Networking']>50
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# Name: Social Networking, dtype: bool

# %%
df[df['Social Networking']>50].head(10)
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 14     14  05/01/19  Wednesday                 127                 90
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# ...

# %%
df[df['Week Day']=='Wednesday']
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 7       7  04/24/19  Wednesday                 135                 98
# 14     14  05/01/19  Wednesday                 127                 90
# 21     21  05/08/19  Wednesday                 122                 53
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 7                       3     33            16                   0
# 14                      0     10             7                   0
# 21                     25     26            15                   0
#
#     Entertainment  Creativity  Yoga
# 0               0           0     0
# 7               0           0     0
# 14              0           0     1
# 21              0           0     1

# %%
df[(df['Week Day']=='Wednesday')|(df['Week Day']=='Sunday')]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 4       4  04/21/19     Sunday                  56                 35
# 7       7  04/24/19  Wednesday                 135                 98
# 11     11  04/28/19     Sunday                  85                 42
# 14     14  05/01/19  Wednesday                 127                 90
# 18     18  05/05/19     Sunday                 133                109
# 21     21  05/08/19  Wednesday                 122                 53
# 25     25  05/12/19     Sunday                  52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 4                       2     43             3                   0
# 7                       3     33            16                   0
# ...

# %%
df[df['Week Day'].isin(['Wednesday','Sunday'])]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 4       4  04/21/19     Sunday                  56                 35
# 7       7  04/24/19  Wednesday                 135                 98
# 11     11  04/28/19     Sunday                  85                 42
# 14     14  05/01/19  Wednesday                 127                 90
# 18     18  05/05/19     Sunday                 133                109
# 21     21  05/08/19  Wednesday                 122                 53
# 25     25  05/12/19     Sunday                  52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 4                       2     43             3                   0
# 7                       3     33            16                   0
# ...
