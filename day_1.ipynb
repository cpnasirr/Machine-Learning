# %% [markdown]
# <a href="https://colab.research.google.com/github/cpnasirr/Machine-Learning/blob/Colab/day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-4101ab8d-bab4-4942-a0af-dbb7f852ca17" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4101ab8d-bab4-4942-a0af-dbb7f852ca17">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv(next(iter(uploaded)))
df.head()
# Out:
#          x         y
# 0  0.00000  4.447692
# 1  0.02004  5.024612
# 2  0.04008  5.869593
# 3  0.06012  4.722490
# 4  0.08016  4.877101

# %%
import pandas as pd
from google.colab import files
myFile= files.upload()
# Out:
#      <input type="file" id="files-b48de41a-7827-4135-8393-656b80bbc7c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b48de41a-7827-4135-8393-656b80bbc7c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fl= pd.read_csv(next(iter(myFile)))
fl.head(10)
# Out:
#           x         y
# 0  0.000000 -0.155043
# 1  0.020040  0.081809
# 2  0.040080 -0.014298
# 3  0.060120  0.143978
# 4  0.080160  0.019553
# 5  0.100200  0.141060
# 6  0.120240  0.228853
# 7  0.140281  0.113572
# 8  0.160321  0.330784
# 9  0.180361  0.320854

# %%
import pandas as pd
from google.colab import files
myFile= files.upload()
#fr=pd.read_csv(linear_data.csv)
#fr.head()
# Out:
#      <input type="file" id="files-0dcb25d5-a91c-4848-9319-970ba59e6e48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dcb25d5-a91c-4848-9319-970ba59e6e48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fr=pd.read_csv(next(iter(myFile)))
fr.head()
# Out:
#          x         y
# 0  0.00000  4.447692
# 1  0.02004  5.024612
# 2  0.04008  5.869593
# 3  0.06012  4.722490
# 4  0.08016  4.877101

# %%
fr.head(10)
# Out:
#           x         y
# 0  0.000000  4.447692
# 1  0.020040  5.024612
# 2  0.040080  5.869593
# 3  0.060120  4.722490
# 4  0.080160  4.877101
# 5  0.100200  5.046555
# 6  0.120240  5.374993
# 7  0.140281  5.543020
# 8  0.160321  5.954347
# 9  0.180361  5.610471

# %%
df= pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city=[('dhaka','mirpur'),('magura','vina'),('khulna','collegepara'),('barisal','golachipa')]
df1= pd.DataFrame(city)
df1
# Out:
#          0            1
# 0    dhaka       mirpur
# 1   magura         vina
# 2   khulna  collegepara
# 3  barisal    golachipa

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
#  1   1       4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
df.shape
# Out:
# (4, 2)

# %%
row,col= df.shape

# %%
row
# Out:
# 4

# %%
col
# Out:
# 2

# %%
df3=pd.DataFrame(city,columns=['City_in_BD','Local_city'],index=['c1','c2','c3','c4'])
df3
# Out:
#    City_in_BD   Local_city
# c1      dhaka       mirpur
# c2     magura         vina
# c3     khulna  collegepara
# c4    barisal    golachipa

# %%
city1=['dhaka','magura','khulna','barisal']
city2=['nuakhali','kustia','pabna','jamalpur']
df4=pd.DataFrame(zip(city1,city2),columns=['city1','city2'])
df4
# Out:
#      city1     city2
# 0    dhaka  nuakhali
# 1   magura    kustia
# 2   khulna     pabna
# 3  barisal  jamalpur
